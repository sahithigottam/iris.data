# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the dataset to python environment.

# %%
filename = '/Users/sahithi/Desktop/Sahithi_Datascience/iris.xls'

# %%
df = df = pd.read_excel(filename)

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
df.tail()
# Out:
#       SL   SW   PL   PW  Classification
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# ## Display the columns in the dataset.

# %%
list(df.columns)
# Out:
# ['SL', 'SW', 'PL', 'PW', 'Classification', 'sepal_ratio', 'petal_ratio']

# %% [markdown]
# ## Calculate the mean of each column of the dataset.

# %%
mean1 = df[["SL","SW","PL","PW"]].mean()

# %%
print(mean1)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## Check for the null values present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
df['Classification'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
df["sepal_ratio"] = df['SL']/df['SW']

# %%
df["petal_ratio"] = df['PL']/df['PW']

# %%
iris_setosa = df['Classification'] == 'Iris-setosa'

# %%
df[iris_setosa].head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
df1 = df.loc[iris_setosa,:]

# %%
print(df1)
# Out:
#      SL   SW   PL   PW Classification  sepal_ratio  petal_ratio
# 0   5.1  3.5  1.4  0.2    Iris-setosa     1.457143     7.000000
# 1   4.9  3.0  1.4  0.2    Iris-setosa     1.633333     7.000000
# 2   4.7  3.2  1.3  0.2    Iris-setosa     1.468750     6.500000
# 3   4.6  3.1  1.5  0.2    Iris-setosa     1.483871     7.500000
# 4   5.0  3.6  1.4  0.2    Iris-setosa     1.388889     7.000000
# 5   5.4  3.9  1.7  0.4    Iris-setosa     1.384615     4.250000
# 6   4.6  3.4  1.4  0.3    Iris-setosa     1.352941     4.666667
# 7   5.0  3.4  1.5  0.2    Iris-setosa     1.470588     7.500000
# 8   4.4  2.9  1.4  0.2    Iris-setosa     1.517241     7.000000
# 9   4.9  3.1  1.5  0.1    Iris-setosa     1.580645    15.000000
# 10  5.4  3.7  1.5  0.2    Iris-setosa     1.459459     7.500000
# 11  4.8  3.4  1.6  0.2    Iris-setosa     1.411765     8.000000
# 12  4.8  3.0  1.4  0.1    Iris-setosa     1.600000    14.000000
# 13  4.3  3.0  1.1  0.1    Iris-setosa     1.433333    11.000000
# ...

# %%
df1.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification', 'sepal_ratio', 'petal_ratio'], dtype='object')

# %%
sepal_ratio1 = df1.loc[:"sepal_ratio",].values

# %%
petal_ratio1 = df1.loc[:"petal_ratio",].values

# %%
plt.figure()
plt.hist((df1["sepal_ratio"],df1["petal_ratio"]),label =["sepal_ratio","petal_ratio"],alpha=0.5)
plt.legend(borderpad= 0.5,fontsize=10)
plt.title("ratio of sepals and lengths")
plt.show()

# %%
sepal_ratio1= df1.loc[:'sepal_ratio'].values

# %%
petal_ratio1 = df1.loc[:'petal_ratio'].values

# %%
iris_versicolor = df['Classification']== 'Iris-versicolor'

# %%
df2 = df.loc[iris_versicolor,:]

# %%
print(x)
# Out:
# Empty DataFrame
# Columns: [SL, SW, PL, PW, Classification]
# Index: []

# %%
print(df2)
# Out:
#      SL   SW   PL   PW   Classification
# 50  7.0  3.2  4.7  1.4  Iris-versicolor
# 51  6.4  3.2  4.5  1.5  Iris-versicolor
# 52  6.9  3.1  4.9  1.5  Iris-versicolor
# 53  5.5  2.3  4.0  1.3  Iris-versicolor
# 54  6.5  2.8  4.6  1.5  Iris-versicolor
# 55  5.7  2.8  4.5  1.3  Iris-versicolor
# 56  6.3  3.3  4.7  1.6  Iris-versicolor
# 57  4.9  2.4  3.3  1.0  Iris-versicolor
# 58  6.6  2.9  4.6  1.3  Iris-versicolor
# 59  5.2  2.7  3.9  1.4  Iris-versicolor
# 60  5.0  2.0  3.5  1.0  Iris-versicolor
# 61  5.9  3.0  4.2  1.5  Iris-versicolor
# 62  6.0  2.2  4.0  1.0  Iris-versicolor
# 63  6.1  2.9  4.7  1.4  Iris-versicolor
# 64  5.6  2.9  3.6  1.3  Iris-versicolor
# 65  6.7  3.1  4.4  1.4  Iris-versicolor
# 66  5.6  3.0  4.5  1.5  Iris-versicolor
# 67  5.8  2.7  4.1  1.0  Iris-versicolor
# 68  6.2  2.2  4.5  1.5  Iris-versicolor
# 69  5.6  2.5  3.9  1.1  Iris-versicolor
# 70  5.9  3.2  4.8  1.8  Iris-versicolor
# 71  6.1  2.8  4.0  1.3  Iris-versicolor
# ...

# %%
iris_virginica   = df['Classification']=='Iris-virginica'

# %%
df3 = df.loc[iris_virginica,:]

# %%
print(df3)
# Out:
#       SL   SW   PL   PW  Classification
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
sepal_length1 = df1.loc

# %%
sepal_length2 =

# %%
sepal_length3 =

# %%
plt.figure()
plt.hist((df1["SL"],df2["SL"],df3["SL"]),label =["Iris-setosa","Iris-versicolor","Iris-virginica"],alpha=0.5)
plt.legend(borderpad= 0.5,fontsize=10)
plt.title("comparison of sepal lengths")
plt.show()

# %%
sns.pairplot(df)

# %%
sns.boxplot(x=("sepal_ratio"),y=("petal_ratio"),data=df1)
# Out:
# <AxesSubplot:xlabel='sepal_ratio', ylabel='petal_ratio'>
